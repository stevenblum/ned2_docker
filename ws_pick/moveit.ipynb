# %%
import os
import sys
import yaml
import rclpy
import numpy as np

# message libraries
from geometry_msgs.msg import PoseStamped, Pose

# moveit_py
from moveit.planning import MoveItPy
from moveit.core.robot_state import RobotState

# config file libraries
from moveit_configs_utils import MoveItConfigsBuilder
from ament_index_python.packages import get_package_share_directory

# %%
urdf_file = os.path.join(
    get_package_share_directory("niryo_ned_description"),
    "urdf/ned2",
    #"niryo_ned2.urdf.xacro",
    "niryo_ned2_gripper1_n_camera.urdf.xacro"

)
srdf_file = "/scripts/sim/niryo_ned2_gripper.srdf"

moveit_config = (
        MoveItConfigsBuilder("niryo_ned2")
        .robot_description(file_path=urdf_file)
        .joint_limits(file_path="config/joint_limits.yaml")
        .robot_description_semantic(file_path=srdf_file)
        .robot_description_kinematics(file_path="config/kinematics.yaml")
        .trajectory_execution(file_path="config/moveit_controllers.yaml")
        .planning_pipelines(
            pipelines=["ompl", "chomp", "pilz_industrial_motion_planner", "stomp"]
        )
        .to_moveit_configs()
    )

# %%
# 1) Exact URDF you load elsewhere
urdf_file = os.path.join(
    get_package_share_directory("niryo_ned_description"),
    "urdf", "ned2",
    "niryo_ned2_gripper1_n_camera.urdf.xacro",
)

# 2) Use the real MoveIt config package (adjust this if yours differs)
moveit_pkg = "niryo_ned2_moveit_config"  # <- ensure this package exists in your ROS env
pkg_share = get_package_share_directory(moveit_pkg)

srdf_file = "/scripts/sim/niryo_ned2_gripper.srdf"
kin_yaml  = os.path.join(pkg_share, "config", "kinematics.yaml")
jl_yaml   = os.path.join(pkg_share, "config", "joint_limits.yaml")
ctrl_yaml = os.path.join(pkg_share, "config", "moveit_controllers.yaml")
ompl_yaml = os.path.join(pkg_share, "config", "ompl_planning.yaml")

# 3) IMPORTANT: robot_name must match the URDF robot name
moveit_config = (
    MoveItConfigsBuilder(
        robot_name="niryo_ned2_gripper1_n_camera",
        package_name=moveit_pkg,  # lets relative paths resolve
    )
    .robot_description(file_path=urdf_file)               # xacro ok
    .robot_description_semantic(file_path=srdf_file)      # SRDF with matching robot name
    .robot_description_kinematics(file_path=kin_yaml)
    .joint_limits(file_path=jl_yaml)
    .trajectory_execution(file_path=ctrl_yaml)
    .planning_pipelines(pipelines=["ompl", "chomp", "pilz_industrial_motion_planner", "stomp"])               # enable OMPL
    .to_moveit_configs()
)

moveit = MoveItPy(node_name="moveit_py", config_dict=moveit_config.to_dict())
arm = moveit.get_planning_component("arm")
# Out:
# [INFO] [1763126951.891463363] [moveit_1573018812.moveit.py.cpp_initializer]: Initialize node parameters
# [INFO] [1763126951.891509483] [moveit_1573018812.moveit.py.cpp_initializer]: Initialize node and executor
# [WARN] [1763126951.892023789] [rcl.logging_rosout]: Publisher already registered for node name: 'moveit_py'. If this is due to multiple nodes with the same name then all logs for the logger named 'moveit_py' will go out over the existing publisher. As soon as any node with that name is destructed it will unregister the publisher, preventing any further logs for that name from being published on the rosout topic.
# [INFO] [1763126951.900042612] [moveit_1573018812.moveit.py.cpp_initializer]: Spin separate thread
# [INFO] [1763126951.903444649] [moveit_1573018812.moveit.ros.rdf_loader]: Loaded robot model in 0.00332695 seconds
# [INFO] [1763126951.903470731] [moveit_1573018812.moveit.core.robot_model]: Loading robot model 'niryo_ned2_gripper1_n_camera'...
# [INFO] [1763126951.942810424] [moveit_1573018812.moveit.kinematics.kdl_kinematics_plugin]: Joint weights for group 'arm': 1 1 1 1 1 1
# [INFO] [1763126952.071949979] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Publishing maintained planning scene on 'monitored_planning_scene'
# [INFO] [1763126952.072044742] [moveit_1573018812.moveit.ros.moveit_cpp]: Listening to 'joint_states' for joint states
# [INFO] [1763126952.072352675] [moveit_1573018812.moveit.ros.current_state_monitor]: Listening to joint states on topic 'joint_states'
# [INFO] [1763126952.072632735] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to '/attached_collision_object' for attached collision objects
# [INFO] [1763126952.072643135] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopping existing planning scene publisher.
# [INFO] [1763126952.072722433] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopped publishing maintained planning scene.
# [INFO] [1763126952.072958928] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Publishing maintained planning scene on 'monitored_planning_scene'
# [INFO] [1763126952.073000912] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Starting planning scene monitor
# [INFO] [1763126952.073228924] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to '/planning_scene'
# [INFO] [1763126952.073236717] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Starting world geometry update monitor for collision objects, attached objects, octomap updates.
# [INFO] [1763126952.073639437] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to 'collision_object'
# [INFO] [1763126952.073850233] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to 'planning_scene_world' for planning scene world geometry
# [WARN] [1763126952.074628639] [moveit_1573018812.moveit.ros.occupancy_map_monitor]: Resolution not specified for Octomap. Assuming resolution = 0.1 instead
# [ERROR] [1763126952.074641277] [moveit_1573018812.moveit.ros.occupancy_map_monitor]: No 3D sensor plugin(s) defined for octomap updates
# [ERROR] [1763126952.149752932] [moveit_1573018812.moveit.ros.moveit_cpp]: Failed to load any planning pipelines.
# [FATAL] [1763126952.149798597] [moveit_1573018812.moveit.ros.moveit_cpp]: Failed to load planning pipelines from parameter server
# [INFO] [1763126952.323214771] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopped publishing maintained planning scene.
# [INFO] [1763126952.323257819] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopping world geometry monitor
# [INFO] [1763126952.323261144] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopping planning scene monitor
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 33
#      18 # 3) IMPORTANT: robot_name must match the URDF robot name
#      19 moveit_config = (
#      20     MoveItConfigsBuilder(
#      21         robot_name="niryo_ned2_gripper1_n_camera",
#    (...)     30     .to_moveit_configs()
#      31 )
# ---> 33 moveit = MoveItPy(node_name="moveit_py", config_dict=moveit_config.to_dict())
#      34 arm = moveit.get_planning_component("arm")
#
# RuntimeError: Failed to load planning pipelines from parameter server

# %%
# initialise rclpy (only for logging purposes)
#rclpy.init()

# instantiate moveit_py instance and a planning component for the panda_arm
ned2 = MoveItPy(node_name="moveit_py", config_dict=moveit_config.to_dict())
ned2 = panda.get_planning_component("ned2_arm")
# Out:
# [INFO] [1763126960.774079115] [moveit_1573018812.moveit.py.cpp_initializer]: Initialize node parameters
# [INFO] [1763126960.774129635] [moveit_1573018812.moveit.py.cpp_initializer]: Initialize node and executor
# [WARN] [1763126960.774877789] [rcl.logging_rosout]: Publisher already registered for node name: 'moveit_py'. If this is due to multiple nodes with the same name then all logs for the logger named 'moveit_py' will go out over the existing publisher. As soon as any node with that name is destructed it will unregister the publisher, preventing any further logs for that name from being published on the rosout topic.
# [INFO] [1763126960.791277089] [moveit_1573018812.moveit.py.cpp_initializer]: Spin separate thread
# [INFO] [1763126960.796381819] [moveit_1573018812.moveit.ros.rdf_loader]: Loaded robot model in 0.00495614 seconds
# [INFO] [1763126960.796401405] [moveit_1573018812.moveit.core.robot_model]: Loading robot model 'niryo_ned2_gripper1_n_camera'...
# [INFO] [1763126960.824674209] [moveit_1573018812.moveit.kinematics.kdl_kinematics_plugin]: Joint weights for group 'arm': 1 1 1 1 1 1
# [INFO] [1763126960.936455770] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Publishing maintained planning scene on 'monitored_planning_scene'
# [INFO] [1763126960.936548837] [moveit_1573018812.moveit.ros.moveit_cpp]: Listening to 'joint_states' for joint states
# [INFO] [1763126960.936837987] [moveit_1573018812.moveit.ros.current_state_monitor]: Listening to joint states on topic 'joint_states'
# [INFO] [1763126960.937065697] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to '/attached_collision_object' for attached collision objects
# [INFO] [1763126960.937072724] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopping existing planning scene publisher.
# [INFO] [1763126960.937152837] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopped publishing maintained planning scene.
# [INFO] [1763126960.937377453] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Publishing maintained planning scene on 'monitored_planning_scene'
# [INFO] [1763126960.937420204] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Starting planning scene monitor
# [INFO] [1763126960.937773003] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to '/planning_scene'
# [INFO] [1763126960.937779452] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Starting world geometry update monitor for collision objects, attached objects, octomap updates.
# [INFO] [1763126960.938200310] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to 'collision_object'
# [INFO] [1763126960.938385422] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Listening to 'planning_scene_world' for planning scene world geometry
# [WARN] [1763126960.939156502] [moveit_1573018812.moveit.ros.occupancy_map_monitor]: Resolution not specified for Octomap. Assuming resolution = 0.1 instead
# [ERROR] [1763126960.939169240] [moveit_1573018812.moveit.ros.occupancy_map_monitor]: No 3D sensor plugin(s) defined for octomap updates
# [ERROR] [1763126961.012362756] [moveit_1573018812.moveit.ros.moveit_cpp]: Failed to load any planning pipelines.
# [FATAL] [1763126961.012413118] [moveit_1573018812.moveit.ros.moveit_cpp]: Failed to load planning pipelines from parameter server
# [INFO] [1763126961.187654601] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopped publishing maintained planning scene.
# [INFO] [1763126961.187684408] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopping world geometry monitor
# [INFO] [1763126961.187688717] [moveit_1573018812.moveit.ros.planning_scene_monitor]: Stopping planning scene monitor
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 5
#       1 # initialise rclpy (only for logging purposes)
#       2 #rclpy.init()
#       3
#       4 # instantiate moveit_py instance and a planning component for the panda_arm
# ----> 5 ned2 = MoveItPy(node_name="moveit_py", config_dict=moveit_config.to_dict())
#       6 ned2 = panda.get_planning_component("ned2_arm")
#
# RuntimeError: Failed to load planning pipelines from parameter server

# %%
def plan_and_execute(
        robot,
        planning_component,
        single_plan_parameters=None,
        multi_plan_parameters=None,
):
        """A helper function to plan and execute a motion."""
        # plan to goal
        if multi_plan_parameters is not None:
                plan_result = planning_component.plan(
                        multi_plan_parameters=multi_plan_parameters
                )
        elif single_plan_parameters is not None:
                plan_result = planning_component.plan(
                single_plan_parameters=single_plan_parameters
        )
        else:
                plan_result = planning_component.plan()

        # execute the plan
        if plan_result:
                robot_trajectory = plan_result.trajectory
                robot.execute(robot_trajectory, controllers=[])
        else:
                print("Planning failed")
